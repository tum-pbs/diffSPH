# %%
# %matplotlib widget
import torch
import os
import copy
os.environ['TORCH_CUDA_ARCH_LIST'] = f'{torch.cuda.get_device_properties(0).major}.{torch.cuda.get_device_properties(0).minor}'

import warnings
from tqdm import TqdmExperimentalWarning
warnings.filterwarnings("ignore", category=TqdmExperimentalWarning)
from tqdm.autonotebook import tqdm

import matplotlib.pyplot as plt

from diffSPH.operations import sph_operation, mod
from diffSPH.sampling import buildDomainDescription, sampleRegularParticles
from diffSPH.modules.eos import idealGasEOS
from diffSPH.schema import getSimulationScheme
from diffSPH.reference.sod import buildSod_reference, sodInitialState, generateSod1D
from diffSPH.modules.adaptiveSmoothingASPH import n_h_to_nH
from diffSPH.reference.sod import plotSod
from diffSPH.reference.hydrostatic import generateHydroStatic
from diffSPH.kernels import KernelType
from diffSPH.plotting import visualizeParticles, updatePlot
from diffSPH.sampling import buildDomainDescription
from diffSPH.modules.adaptiveSmoothingASPH import n_h_to_nH
from diffSPH.plotting import visualizeParticles, updatePlot
from diffSPH.integration import getIntegrator
from diffSPH.util import volumeToSupport
from diffSPH.boundary import sampleDomainSDF
from diffSPH.kernels import getKernelEnum
from diffSPH.sdf import getSDF, sdfFunctions, operatorDict, sampleSDF
from diffSPH.regions import buildRegion, filterRegion, plotRegions
from diffSPH.modules.timestep import computeTimestep
# from diffSPH.schemes.weaklyCompressible import updateBodyParticles, initializeWeaklyCompressibleSimulation
from diffSPH.schemes.deltaSPH import deltaPlusSPHScheme, DeltaPlusSPHSystem
from torch.profiler import profile,  ProfilerActivity
from diffSPH.integration import IntegrationSchemeType
from diffSPH.enums import *

# %%
device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')
# device = torch.device('cpu')
dtype = torch.float32

nx = 256
dim = 2
kernel = KernelType.B7
targetNeighbors = n_h_to_nH(4,dim)
CFL = 0.3
goalRadius = 0.8

gamma = 1.4
rho_low = 1
rho_high = 2
samplingBefore = True

scheme = SimulationScheme.CRKSPH
integrationScheme = IntegrationSchemeType.rungeKutta2

viscositySwitch = ViscositySwitch.NoneSwitch
supportScheme = AdaptiveSupportScheme.OwenScheme

L = 2
dx = L/nx
aspect = 1
band = 20
domain = buildDomainDescription(l = L, dim = dim, periodic = True, device = device, dtype = dtype)
domain.min[0] = -L/2/aspect
domain.max[0] =  L/2/aspect
domain.min[1] = -L/2 - band * dx
domain.max[1] =  L/2 + band * dx


simulator, SimulationSystem, solverConfig, integrator = getSimulationScheme(
     scheme, kernel, integrationScheme, 
     gamma, targetNeighbors, domain, 
     viscositySwitch=viscositySwitch, supportScheme = supportScheme)
integrationScheme = getIntegrator(integrationScheme)

# config = {
#     'domain': domain,
#     'kernel': wrappedKernel,
#     'targetNeighbors': targetNeighbors,
#     'verletScale': 1.4,
#     'shifting': {'scheme': 'delta', 'freeSurface': False},
#     'surfaceDetection': {'active': False},
#     'pressure':{'term': 'Antuono'},
#     'fluid': {'rho0': 1, 'c_s': 20},    
#     'gravity': {'active': False, 'magnitude': 1, 'mode': 'potential'},
#     'particle': {'nx': nx + 2 * band, 'dx': L/nx, 'targetNeighbors': targetNeighbors, 'band': band},
#     'timestep':{'CFL': CFL, 'dt': 1e-3, 'maxDt': 1e-2, 'minDt': 1e-6}
# }

solverConfig['particle'] = {
     'nx': 0.5*nx,
     'dx': (2*L)/nx,
     'targetNeighbors': targetNeighbors,
     'band': 0
}

# %%
area = solverConfig['particle']['dx']**2

# %%
band*dx
# Out:
# 0.15625

# %%
# inner_sdf = lambda points: sampleSDF(points, lambda x: getSDF('box')['function'](x, torch.tensor([1/3,1/3]).to(points.device)))
# inner_sdf_ = lambda x: getSDF('circle')['function'](x, torch.tensor(L/4).to(x.device))
inner_sdf_ = lambda x: getSDF('box')['function'](x, torch.tensor([L/4,L/4]).to(x.device))
inner_sdf = lambda points: sampleSDF(points, inner_sdf_, invert = False)
outer_sdf_ = lambda x: getSDF('box')['function'](x, torch.tensor([L,L]).to(x.device))

outer_sdf_cutaway = operatorDict['difference'](
    outer_sdf_,
    # operatorDict['invert'](inner_sdf_),
    inner_sdf_
    # outer_sdf_
)

outer_sdf = lambda points: sampleSDF(points, outer_sdf_cutaway, invert = False)

fluid_sdf = lambda points: sampleSDF(points, operatorDict['translate'](lambda x: getSDF('box')['function'](x, torch.tensor([L/2 / aspect,L/2 + band * dx]).to(x.device)), torch.tensor([0,0]).to(points.device)), invert = False)


bottom_sdf = lambda points: sampleSDF(points, operatorDict['translate'](lambda x: getSDF('box')['function'](x, torch.tensor([L/2/aspect,band * dx / 2 + dx/2]).to(x.device)), torch.tensor([0,-L/2- band * dx/2-dx/4]).to(points.device)), invert = False)
top_sdf = lambda points: sampleSDF(points, operatorDict['translate'](lambda x: getSDF('box')['function'](x, torch.tensor([L/2/aspect,band * dx / 2 + dx/2]).to(x.device)), torch.tensor([0,L/2 + band * dx/2+dx/4]).to(points.device)), invert = False)


# inlet_sdf = lambda points: sampleSDF(points, operatorDict['translate'](lambda x: getSDF('box')['function'](x, torch.tensor([0.125,0.125]).to(points.device)), torch.tensor([-0.5,0.5]).to(points.device)), invert = False)
# outlet_sdf = lambda points: sampleSDF(points, operatorDict['translate'](lambda x: getSDF('box')['function'](x, torch.tensor([0.125,0.125]).to(points.device)), torch.tensor([0.5,-0.5]).to(points.device)), invert = False)
# outletBuffer_sdf = lambda points: sampleSDF(points, operatorDict['translate'](lambda x: getSDF('box')['function'](x, torch.tensor([0.25,0.25]).to(points.device)), torch.tensor([0.5,-0.5]).to(points.device)), invert = False)

rho_b = rho_low
rho_t = rho_high
delta = 0.0025
g = 1/2
gamma = solverConfig['fluid']['gamma']
P_0 = rho_t / gamma
print(gamma)

def rayleighTaylor_rho(positions, rho_b, rho_t, delta):
    # print('Enforcing Rayleigh-Taylor density for ', positions.shape[0], ' particles')
    y = positions[:,1]
    rho_y = rho_b + (rho_t - rho_b) * (1 + torch.exp(-(y - 0.0) / delta))**(-1)
    return rho_y
def rayleighTaylor_u(positions, rho_b, rho_t, delta, g, gamma):
    y = positions[:,1]
    rho_y = rayleighTaylor_rho(positions, rho_b, rho_t, delta)
    P_0 = rho_t / gamma
    P = P_0 - g * rho_y * (y - 0.0)
    u = P / rho_y / (gamma - 1)
    return u


regions = []
solverConfig['particle']['shortEdge'] = True
regions.append(buildRegion(sdf = top_sdf, config = solverConfig, type = 'dirichlet',
    dirichletValues={
        'velocities': lambda x, mask, state, t, dt: torch.zeros_like(x),
        'densities': lambda x, mask, state, t, dt: rayleighTaylor_rho(x, rho_low, rho_high, delta),
        'internalEnergies': lambda x, mask, state, t, dt: rayleighTaylor_u(x, rho_low, rho_high, delta, g, gamma),
    },
    updateValues={
        'velocities': lambda x, mask, state, t, dt: torch.zeros_like(x),
        'positions': lambda x, mask, state, t, dt: torch.zeros_like(x),
        'internalEnergies': lambda x, mask, state, t, dt: torch.zeros_like(x[:,0])
    })
)
regions.append(buildRegion(sdf = bottom_sdf, config = solverConfig, type = 'dirichlet',
    dirichletValues={
        'velocities': lambda x, mask, state, t, dt: torch.zeros_like(x),
        'densities': lambda x, mask, state, t, dt: rayleighTaylor_rho(x, rho_low, rho_high, delta),
        'internalEnergies': lambda x, mask, state, t, dt: rayleighTaylor_u(x, rho_low, rho_high, delta, g, gamma),
    },
    updateValues={
        'velocities': lambda x, mask, state, t, dt: torch.zeros_like(x),
        'positions': lambda x, mask, state, t, dt: torch.zeros_like(x),
        'internalEnergies': lambda x, mask, state, t, dt: torch.zeros_like(x[:,0])
    })
)


regions.append(buildRegion(sdf = fluid_sdf, config = solverConfig, type = 'fluid'))


# regions.append(buildRegion(sdf = outer_sdf, config = solverConfig, type = 'fluid', initialConditions={'densities': rho_low, 'masses': area * rho_low}))

regions[-1]['particles'].masses[regions[-1]['particles'].positions[:,1] > 0.] = area * rho_high
regions[-1]['particles'].densities[regions[-1]['particles'].positions[:,1] > 0.] = rho_high

import numpy as np
x = regions[-1]['particles'].positions[:,0]
y = regions[-1]['particles'].positions[:,1]

rho_y = rho_b + (rho_t - rho_b) * (1 + torch.exp(-(y - 0) / delta))**(-1)

regions[-1]['particles'] = regions[-1]['particles']._replace(masses = area * rho_y, densities = rho_y)

delta_y = delta * 5
v_y = delta_y * (1 + torch.cos(2 * np.pi * (x + 0.25))) * (1 + torch.cos(5 * np.pi * (y - 0)))

P = P_0 - g * rho_y * (y - 0)


mask = torch.logical_and(y >= 0.0, y <= 1.0)

print('Min rho: ', rho_y[mask].min().item())
print('Max rho: ', rho_y[mask].max().item())
print('Min pressure: ', P[mask].min().item())
print('Max pressure: ', P[mask].max().item())


solverConfig['gravity']['active'] = True
solverConfig['gravity']['magnitude'] = g
solverConfig['gravity']['mode'] = 'directional'
solverConfig['gravity']['direction'] = torch.tensor([0, -1], device = device, dtype = dtype)




# regions.append(buildRegion(sdf = inlet_sdf, config = config, type = 'inlet', dirichletValues={'densities': config['fluid']['rho0'], 'velocities': torch.tensor([1,0], device = device, dtype = dtype)}, updateValues = {'densities': 0, 'velocities': torch.tensor([0,0], device = device, dtype = dtype)}))

# regions.append(buildRegion(sdf = outlet_sdf, config = config, type = 'outlet'))
# regions.append(buildRegion(sdf = outletBuffer_sdf, config = config, type = 'buffer', bufferValues = ['densities', 'velocities', 'pressures']))

# regions.append(buildRegion(sdf = box_sdf, config = config, type = 'dirichlet', dirichletValues={'densities': 2.0, 'velocities': torch.tensor([1,2], device = device, dtype = dtype), 'pressures': lambda x: torch.where(x[:,0] > 0, 0.0, 1.0)}, updateValues = {'densities': 2.0}))


for region in regions:
    region = filterRegion(region, regions)


fig, axis = plt.subplots(1, 1, figsize=(5, 5), squeeze=False)

axis[0,0].set_xlim(domain.min[0].cpu().numpy() - dx, domain.max[0].cpu().numpy() + dx)
axis[0,0].set_ylim(domain.min[1].cpu().numpy() - dx, domain.max[1].cpu().numpy() + dx)
axis[0,0].set_aspect('equal', adjustable='box')
    
plotRegions(regions, axis[0,0], plotFluid = False, plotParticles = False)
axis[0,0].set_aspect('equal', adjustable='box')
print('Number of Particles: ', sum([region['particles'].positions.shape[0] for region in regions ]))

print('Particle dx: ', regions[0]['particles'].masses.mean().item()**(1/2))
print('dx', dx)
# axis[0,0].axhline(0.5)
# axis[0,0].axhline(0)
# axis[0,0].axhline(1)
# Out:
# 1.4
# Min rho:  1.9579122066497803
# Max rho:  2.0
# Min pressure:  0.4363839626312256
# Max pressure:  1.4209233522415161
# Number of Particles:  21504
# Particle dx:  0.015625
# dx 0.0078125
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from diffSPH.schemes.initializers import initializeSimulation, updateBodyParticles

# %%
particleState, config, rigidBodies = initializeSimulation(scheme, solverConfig, regions)
particleState.alpha0s = torch.ones_like(particleState.densities)
particleState.divergence = torch.zeros_like(particleState.densities)
particles = copy.deepcopy(particleState)

# %%
from diffSPH.neighborhood import evaluateNeighborhood, filterNeighborhoodByKind, SupportScheme
from diffSPH.modules.eos import idealGasEOS
from diffSPH.modules.compressible import CompressibleState
from diffSPH.modules.density import computeDensity
from diffSPH.neighborhood import PointCloud, DomainDescription, buildNeighborhood, filterNeighborhood, coo_to_csrsc, coo_to_csr

bandMask = torch.logical_and(y > -0.4, y < 0.4)

particleState.velocities[bandMask, 1] = v_y[bandMask]

# simulationState = tate
neighborhood, neighbors = evaluateNeighborhood(particleState, domain, kernel, verletScale = 1.0, mode = SupportScheme.SuperSymmetric, priorNeighborhood=None)
numNeighbors = coo_to_csr(filterNeighborhoodByKind(particleState, neighbors.neighbors, which = 'noghost')).rowEntries
densities = computeDensity(particleState, kernel, neighbors.get('noghost'), SupportScheme.Gather, solverConfig)


print(densities[~bandMask].min(), densities[~bandMask].max())

A_, u_, P_, c_s = idealGasEOS(A = None, u = None, P = P, rho = rho_y, gamma = gamma)
particleState.pressures = P_
particleState.internalEnergies = u_


mask = torch.logical_and(y >= 0.0, y <= 1.0)
print('Min rho: ', densities[mask].min().item())
print('Max rho: ', densities[mask].max().item())
print('Min pressure: ', P_[mask].min().item())
print('Max pressure: ', P_[mask].max().item())
# Out:
# tensor(1.0000, device='cuda:0') tensor(2.0000, device='cuda:0')
# Min rho:  1.7321876287460327
# Max rho:  2.0000064373016357
# Min pressure:  0.4363839626312256
# Max pressure:  1.4209233522415161

# %%
print(rho_t *(1/gamma - 1/4))
print(rho_t * (1/gamma + 1/8))
# Out:
# 0.9285714285714286
# 1.6785714285714286

# %%
particleSystem = SimulationSystem(domain, None, 0., copy.deepcopy(particleState), priorStep = None)
for rigidBody in rigidBodies:
    particleState = updateBodyParticles(scheme, particleState, rigidBody)

from diffSPH.modules.timestep import computeTimestep
dt = computeTimestep(scheme, 0, particleSystem.systemState, solverConfig, None)

# %%
fluidParticles = particleSystem.systemState
fig, axis = plt.subplots(1, 2, figsize = (12, 8), squeeze = False)

markerSize = 4
densityPlotState = visualizeParticles(fig, axis[0,0],
                     particles = fluidParticles, 
                     domain = domain, 
                     quantity = densities, 
                     which = 'fluid',
                     visualizeBoth=False,
                     kernel = solverConfig['kernel'],
                     plotDomain = True,
                     cmap = 'RdBu_r',
                     title='Density $\\rho$',
                     markerSize = markerSize,)

velocityPlotState = visualizeParticles(fig, axis[0,1],
                     particles = fluidParticles, 
                     domain = domain, 
                     quantity = fluidParticles.pressures, 
                     which = 'fluid',
                     mapping = 'L2',
                     visualizeBoth=False,
                     kernel = solverConfig['kernel'],
                     plotDomain = True,
                     cmap = 'magma',
                     title='Internal Energy $u$',
                     markerSize = markerSize,)

fig.suptitle(f"Rayleigh-Taylor Instability - Compressible\n{solverConfig['schemeName']}\nParticles: {fluidParticles.positions.shape[0]}, dt: {dt:1.3e}, t: {particleSystem.t:.4f}", fontsize=12)

# axis[0,0].set_ylim(-1,1)
# axis[0,1].set_ylim(-1,1)


fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print((1/gamma - 1/4) * rho_t)
mask = torch.logical_and(y >= 0.0, y <= 1.0)
P[bandMask].min()
# Out:
# 0.9285714285714286
# tensor(1.0301, device='cuda:0')

# %%
imagePrefix = './images/rayleighTaylor/'
os.makedirs(imagePrefix, exist_ok = True)

fig.savefig(f'{imagePrefix}frame_{0:05d}.png', dpi = 200)

# config['diffusion'] = {'alpha': 0.1}
# dt = computeDT(particleSystem.systemState, CFL = CFL, solverConfig = solverConfig)
# print()
dt = computeTimestep(scheme, 0, particleSystem.systemState, solverConfig, None)
dt = 1e-3
# dt = 1e-3
print(dt)

particleSystem, currentState, updates = integrationScheme.function(particleSystem, dt, simulator, config, priorStep = particleSystem.priorStep, verbose = False)
# Out:
# 0.001
# Namespace CRKSPH not found in config. Setting eta_crit to 0.25
# Key eta_fold not found in config["CRKSPH"]. Setting eta_fold to 0.2

# %%
from diffSPH.util import postProcess
postProcess(
    imagePrefix = imagePrefix,
    fps = 50,
    exportName = 'rayleighTaylor2',
    targetLongEdge = 1200
)
# Out:
# Copying video to videos folder
# Done!

# %%
from diffSPH.kernels import Kernel_xi
particles = copy.deepcopy(particleState)
particleSystem = SimulationSystem(domain, None, 0., copy.deepcopy(particleState), priorStep = None)
for rigidBody in rigidBodies:
    particleState = updateBodyParticles(scheme, particleState, rigidBody)


states = []

t = 0
timeLimit = 15
timesteps = int(timeLimit / dt)
plotInterval = 20

for i in (tq:=tqdm(range(timesteps))):
    particleSystem, currentState, updates = integrationScheme.function(particleSystem, dt, simulator, config, priorStep = particleSystem.priorStep, verbose = False)
    particleSystem.priorStep = [updates[-1], currentState[-1]]
    
    c_s = idealGasEOS(A=None, P = None, u = particleSystem.systemState.internalEnergies, rho = particleSystem.systemState.densities, gamma = solverConfig['fluid']['gamma'])[-1]
    c_s_max = c_s.max()
    h_min = particleSystem.systemState.supports.min()
    xi = Kernel_xi(solverConfig['kernel'], particleSystem.systemState.positions.shape[1])

    # particleSystem.systemState.velocities = particleSystem.systemState.velocities * 0.99

    timestepCFL = 0.3
    dt_cfl = timestepCFL * h_min / (c_s_max * xi)
    CFLNumber = (c_s_max * xi * dt) / h_min
    
    print(f'Current dt: {dt:.3g}, CFL dt: {dt_cfl:.3g}, h_min: {h_min:.3g}, c_s_max: {c_s_max:.3g}, xi: {xi:.3g}')
    
    # if i % 100 == 0:
    #     states.append(copy.deepcopy(particleSystem))

    if i % plotInterval == plotInterval - 1 or i == timesteps - 1:

        # rhoMin = particleSystem.systemState.densities.min().detach().cpu().item() / config['fluid']['rho0']
        # rhoMean = particleSystem.systemState.densities.mean().detach().cpu().item() / config['fluid']['rho0']
        # rhoMax = particleSystem.systemState.densities.max().detach().cpu().item() / config['fluid']['rho0']

        # kineticEnergy = 0.5 * particleSystem.systemState.masses / config['fluid']['rho0'] * particleSystem.systemState.densities * torch.linalg.norm(particleSystem.systemState.velocities, dim = -1)**2
        # totalInitialEnergy = (initialKineticEnergy).sum().detach().cpu().item()
        # totalEnergy = (kineticEnergy).sum().detach().cpu().item()

        # fig.suptitle(f'Kolmogorov Flow, ptcls = {particleState.positions.shape[0]}, kernel = {kernel}, neighbors = {targetNeighbors:.2g}, CFL = {CFL}\n$\\rho$ = [{rhoMin:.4g} | {rhoMean:.4g} | {rhoMax:.4g}], $E_0$ = {totalInitialEnergy:.4g}, $E$ = {totalEnergy:.4g}, $\\Delta E$ = {totalEnergy - totalInitialEnergy:.4g}, $t$ = {t:.4g}, $\Delta t$ = {dt:.4g}')
        fig.suptitle(f"Rayleigh-Taylor Instability - Compressible\n{solverConfig['schemeName']}\nParticles: {fluidParticles.positions.shape[0]}, dt: {dt:1.3e}, t: {particleSystem.t:.4f}", fontsize=12)

        updatePlot(densityPlotState, particleSystem.systemState, particleSystem.systemState.densities)
        updatePlot(velocityPlotState, particleSystem.systemState, particleSystem.systemState.internalEnergies)
        # updatePlot(uidPlot, particleSystem.systemState, particleSystem.systemState.pressures)

        # axis[0,0].set_ylim(-1,1)
        # axis[0,1].set_ylim(-1,1)
        
        fig.canvas.draw()
        fig.canvas.flush_events()
        fig.savefig(f'{imagePrefix}frame_{i:05d}.png', dpi = 200)
    # break
    # if i > 90:
        # break
# Out:
#   0%|          | 0/15000 [00:00<?, ?it/s]
# Current dt: 0.001, CFL dt: 0.00291, h_min: 0.0638, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00292, h_min: 0.064, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00291, h_min: 0.064, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00291, h_min: 0.064, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00291, h_min: 0.0639, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00291, h_min: 0.0639, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00291, h_min: 0.0639, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00291, h_min: 0.0639, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00291, h_min: 0.0638, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.0029, h_min: 0.0638, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.0029, h_min: 0.0637, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.0029, h_min: 0.0637, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.0029, h_min: 0.0637, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.0029, h_min: 0.0637, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.0029, h_min: 0.0636, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.0029, h_min: 0.0636, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.0029, h_min: 0.0636, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.0029, h_min: 0.0636, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00289, h_min: 0.0635, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00289, h_min: 0.0635, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00289, h_min: 0.0635, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00289, h_min: 0.0635, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00289, h_min: 0.0634, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00289, h_min: 0.0634, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00289, h_min: 0.0634, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00289, h_min: 0.0634, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00289, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.063, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.063, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.063, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.063, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00287, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0631, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0633, c_s_max: 1.67, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00288, h_min: 0.0632, c_s_max: 1.67, xi: 3.93
# ...
# Current dt: 0.001, CFL dt: 0.000439, h_min: 0.0138, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000437, h_min: 0.0138, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000436, h_min: 0.0137, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000434, h_min: 0.0137, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000433, h_min: 0.0136, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000431, h_min: 0.0136, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00043, h_min: 0.0136, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000429, h_min: 0.0135, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000429, h_min: 0.0135, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000428, h_min: 0.0135, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000428, h_min: 0.0135, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000427, h_min: 0.0135, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000427, h_min: 0.0135, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000427, h_min: 0.0134, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000427, h_min: 0.0135, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000427, h_min: 0.0135, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000428, h_min: 0.0135, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000428, h_min: 0.0135, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000429, h_min: 0.0135, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00043, h_min: 0.0135, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000431, h_min: 0.0136, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000431, h_min: 0.0136, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00043, h_min: 0.0136, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00043, h_min: 0.0135, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00043, h_min: 0.0135, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00043, h_min: 0.0135, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00043, h_min: 0.0136, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000431, h_min: 0.0136, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000432, h_min: 0.0136, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000433, h_min: 0.0136, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000433, h_min: 0.0136, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000433, h_min: 0.0136, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000433, h_min: 0.0136, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000433, h_min: 0.0136, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000433, h_min: 0.0137, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000433, h_min: 0.0137, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000433, h_min: 0.0137, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000434, h_min: 0.0137, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000434, h_min: 0.0137, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000434, h_min: 0.0137, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000434, h_min: 0.0137, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000434, h_min: 0.0137, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000434, h_min: 0.0137, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000435, h_min: 0.0137, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000435, h_min: 0.0137, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000435, h_min: 0.0137, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000436, h_min: 0.0137, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000436, h_min: 0.0138, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000437, h_min: 0.0138, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000437, h_min: 0.0138, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000438, h_min: 0.0138, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000439, h_min: 0.0138, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000441, h_min: 0.0139, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000442, h_min: 0.0139, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000444, h_min: 0.014, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000446, h_min: 0.014, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000448, h_min: 0.0141, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00045, h_min: 0.0142, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000452, h_min: 0.0143, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000455, h_min: 0.0143, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000456, h_min: 0.0144, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000457, h_min: 0.0144, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000457, h_min: 0.0144, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000458, h_min: 0.0144, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000459, h_min: 0.0145, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00046, h_min: 0.0145, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00046, h_min: 0.0145, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000462, h_min: 0.0146, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000463, h_min: 0.0146, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000464, h_min: 0.0146, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000465, h_min: 0.0147, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000467, h_min: 0.0147, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000469, h_min: 0.0148, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00047, h_min: 0.0148, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000472, h_min: 0.0149, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000474, h_min: 0.015, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000476, h_min: 0.015, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000479, h_min: 0.0151, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000481, h_min: 0.0152, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000483, h_min: 0.0152, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000486, h_min: 0.0153, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000487, h_min: 0.0154, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000487, h_min: 0.0154, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000488, h_min: 0.0154, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000488, h_min: 0.0154, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000488, h_min: 0.0154, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000488, h_min: 0.0154, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000488, h_min: 0.0154, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000488, h_min: 0.0154, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000485, h_min: 0.0153, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000482, h_min: 0.0152, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000478, h_min: 0.0151, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000475, h_min: 0.015, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000472, h_min: 0.0149, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000469, h_min: 0.0148, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000465, h_min: 0.0147, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000462, h_min: 0.0146, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000459, h_min: 0.0145, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000456, h_min: 0.0144, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000453, h_min: 0.0143, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00045, h_min: 0.0142, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000447, h_min: 0.0141, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000444, h_min: 0.014, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000441, h_min: 0.0139, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000438, h_min: 0.0138, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000436, h_min: 0.0137, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000433, h_min: 0.0137, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000431, h_min: 0.0136, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000428, h_min: 0.0135, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000426, h_min: 0.0134, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000423, h_min: 0.0133, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000421, h_min: 0.0133, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000419, h_min: 0.0132, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000417, h_min: 0.0131, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000415, h_min: 0.0131, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000414, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000412, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000411, h_min: 0.0129, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00041, h_min: 0.0129, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000408, h_min: 0.0129, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000407, h_min: 0.0128, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000407, h_min: 0.0128, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000406, h_min: 0.0128, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000406, h_min: 0.0128, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000405, h_min: 0.0128, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000405, h_min: 0.0128, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000405, h_min: 0.0128, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000406, h_min: 0.0128, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000406, h_min: 0.0128, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000407, h_min: 0.0128, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000407, h_min: 0.0128, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000408, h_min: 0.0129, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000409, h_min: 0.0129, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000409, h_min: 0.0129, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00041, h_min: 0.0129, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000411, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000411, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000412, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000412, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000413, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000413, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000414, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000414, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000414, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000414, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000414, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000413, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000413, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000413, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000413, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000413, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000413, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000413, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000413, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000413, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000414, h_min: 0.013, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000414, h_min: 0.0131, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000415, h_min: 0.0131, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000416, h_min: 0.0131, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000417, h_min: 0.0132, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000418, h_min: 0.0132, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00042, h_min: 0.0132, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000422, h_min: 0.0133, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000423, h_min: 0.0133, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000426, h_min: 0.0134, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000428, h_min: 0.0135, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000431, h_min: 0.0136, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000433, h_min: 0.0137, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000437, h_min: 0.0138, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00044, h_min: 0.0139, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000444, h_min: 0.014, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000448, h_min: 0.0141, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000451, h_min: 0.0142, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00045, h_min: 0.0142, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000449, h_min: 0.0141, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000448, h_min: 0.0141, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000448, h_min: 0.0141, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000448, h_min: 0.0141, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000448, h_min: 0.0141, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000448, h_min: 0.0141, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000448, h_min: 0.0141, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000448, h_min: 0.0141, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000449, h_min: 0.0141, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000449, h_min: 0.0142, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000449, h_min: 0.0141, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000449, h_min: 0.0141, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000448, h_min: 0.0141, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000449, h_min: 0.0141, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000449, h_min: 0.0141, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000449, h_min: 0.0142, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00045, h_min: 0.0142, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000451, h_min: 0.0142, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000452, h_min: 0.0142, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000453, h_min: 0.0143, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000454, h_min: 0.0143, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000455, h_min: 0.0144, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000456, h_min: 0.0144, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000457, h_min: 0.0144, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000458, h_min: 0.0144, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000459, h_min: 0.0145, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00046, h_min: 0.0145, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000458, h_min: 0.0144, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000454, h_min: 0.0143, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000451, h_min: 0.0142, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000447, h_min: 0.0141, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000443, h_min: 0.014, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00044, h_min: 0.0139, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000437, h_min: 0.0138, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000433, h_min: 0.0137, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.00043, h_min: 0.0136, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000427, h_min: 0.0135, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000424, h_min: 0.0134, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000421, h_min: 0.0133, c_s_max: 2.4, xi: 3.93
# Current dt: 0.001, CFL dt: 0.000418, h_min: 0.0132, c_s_max: 2.4, xi: 3.93

# %%
from diffSPH.modules.CRKSPH import computeCRKVolume, computeGeometricMoments, computeCRKTerms, computeCRKDensity, computeVelocityTensor, computeCRKdvdt, computeCRKdudt

wrappedKernel = solverConfig['kernel']

particles = particleSystem.systemState
neighborhood, neighbors = evaluateNeighborhood(particles, domain, kernel, verletScale = 1.0, mode = SupportScheme.SuperSymmetric, priorNeighborhood=None)
numNeighbors = coo_to_csr(filterNeighborhoodByKind(particles, neighbors.neighbors, which = 'noghost')).rowEntries
densities = computeDensity(particles, kernel, neighbors.get('noghost'), SupportScheme.Gather, solverConfig)

particles.omega = torch.ones_like(particles.masses)
particles.apparentArea = computeCRKVolume(particles, wrappedKernel, neighbors.get('noghost'), SupportScheme.Gather, config)

kernelMoments = computeGeometricMoments(particles, wrappedKernel, neighbors.get('noghost'), SupportScheme.SuperSymmetric, config)

particles.A, particles.B, particles.gradA, particles.gradB = computeCRKTerms(kernelMoments, particles.numNeighbors, particles.supports)

densities = computeCRKDensity(particles, wrappedKernel, neighbors.get('noghost'), SupportScheme.SuperSymmetric, config)

# %%
# fluidParticles = particleSystem.systemState
fig, axis = plt.subplots(1, 2, figsize = (12, 8), squeeze = False)

markerSize = 4
densityPlotState = visualizeParticles(fig, axis[0,0],
                     particles = particles, 
                     domain = domain, 
                     quantity = densities, 
                     which = 'fluid',
                     visualizeBoth=False,
                     kernel = solverConfig['kernel'],
                     plotDomain = True,
                     cmap = 'RdBu_r',
                     title='Density $\\rho$',
                     markerSize = markerSize,)

velocityPlotState = visualizeParticles(fig, axis[0,1],
                     particles = particles, 
                     domain = domain, 
                     quantity = particles.apparentArea, 
                     which = 'fluid',
                     mapping = 'L2',
                     visualizeBoth=False,
                     kernel = solverConfig['kernel'],
                     plotDomain = True,
                     cmap = 'magma',
                     title='Internal Energy $u$',
                     markerSize = markerSize,)

fig.suptitle(f"Rayleigh-Taylor Instability - Compressible\n{solverConfig['schemeName']}\nParticles: {fluidParticles.positions.shape[0]}, dt: {dt:1.3e}, t: {particleSystem.t:.4f}", fontsize=12)

# axis[0,0].set_ylim(-1,1)
# axis[0,1].set_ylim(-1,1)


fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
nx = [32, 64, 128, 256]
c_s = 10

    
if c_s == 20:
    dts = [2e-3, 1e-3, 5e-4, 2.5e-4]
elif c_s == 10:
    dts = [4e-3, 2e-3, 1e-3, 5e-4]
elif c_s == 30:
    dts = [1e-3, 5e-4, 2.5e-4, 1.25e-4]

normalizeEnergy = False
cases = 4
seeds = np.random.randint(0, 2**32 - 1, size = cases)


python wcflows.py --normalizeEnergy --TGV 2 --cs 30 --domainBoundary --obstacle --verbose --nx 256 --dt 1e-4 --velocityNoise --seed 24395732

# %%
import numpy as np

circleCases = 2
dualRegionCases = circleCases
quadRegionCases = circleCases
velocityNoiseCases = circleCases
densityNoiseCases = circleCases
splitLinesX = np.random.rand(quadRegionCases) * 2/2 - 1/2
splitLinesY = np.random.rand(quadRegionCases) * 2/2 - 1/2
velocitySeeds = np.random.randint(0, np.iinfo(np.uint32).max, size=velocityNoiseCases)
densitySeeds = np.random.randint(0, np.iinfo(np.uint32).max, size=densityNoiseCases)
pressureSeeds = np.random.randint(0, np.iinfo(np.uint32).max, size=densityNoiseCases)

nx = [32, 64, 128, 256, 512]
dt = [0.005, 0.0025, 0.001, 0.0005, 0.0001]

for (n, d) in zip(nx, dt):
    for i in range(circleCases):
        print('python regionalShocks.py --regions 1 --timeLimit 4.096 --sdf circle --caseName circleCase --seed {} --nx {} --dt {}'.format(velocitySeeds[i], n, d))
        print('python regionalShocks.py --regions 2 --timeLimit 4.096 --caseName dualRegions --seed {} --nx {} --dt {}'.format(velocitySeeds[i], n, d))
        print('python regionalShocks.py --regions 4 --timeLimit 4.096 --caseName quadRegions --splitLineX {:.3f} --splitLineY {:.3f} --seed {} --nx {} --dt {}'.format(splitLinesX[i], splitLinesY[i], velocitySeeds[i], n, d))
        print(f'python regionalShocks.py --regions 1 --timeLimit 4.096 --velocityNoise --seed {velocitySeeds[i]} --caseName velocityNoise --nx {n} --dt {d}')
        print(f'python regionalShocks.py --regions 1 --timeLimit 4.096 --densityNoise --pressureNoise --densityNoiseSeed {densitySeeds[i]} --pressureNoiseSeed {pressureSeeds[i]} --caseName densityPressureNoise --nx {n} --dt {d}')

# seeds = np.random.randint(0, np.iinfo(np.uint32).max, size=8)
# print(seeds)

# for seed in seeds:
#     print(seed)
# Out:
# python regionalShocks.py --regions 1 --timeLimit 4.096 --sdf circle --caseName circleCase --seed 123625573 --nx 32 --dt 0.005
# python regionalShocks.py --regions 2 --timeLimit 4.096 --caseName dualRegions --seed 123625573 --nx 32 --dt 0.005
# python regionalShocks.py --regions 4 --timeLimit 4.096 --caseName quadRegions --splitLineX -0.164 --splitLineY -0.321 --seed 123625573 --nx 32 --dt 0.005
# python regionalShocks.py --regions 1 --timeLimit 4.096 --velocityNoise --seed 123625573 --caseName velocityNoise --nx 32 --dt 0.005
# python regionalShocks.py --regions 1 --timeLimit 4.096 --densityNoise --pressureNoise --densityNoiseSeed 2792666959 --pressureNoiseSeed 650799304 --caseName densityPressureNoise --nx 32 --dt 0.005
# python regionalShocks.py --regions 1 --timeLimit 4.096 --sdf circle --caseName circleCase --seed 3375572104 --nx 32 --dt 0.005
# python regionalShocks.py --regions 2 --timeLimit 4.096 --caseName dualRegions --seed 3375572104 --nx 32 --dt 0.005
# python regionalShocks.py --regions 4 --timeLimit 4.096 --caseName quadRegions --splitLineX -0.103 --splitLineY -0.149 --seed 3375572104 --nx 32 --dt 0.005
# python regionalShocks.py --regions 1 --timeLimit 4.096 --velocityNoise --seed 3375572104 --caseName velocityNoise --nx 32 --dt 0.005
# python regionalShocks.py --regions 1 --timeLimit 4.096 --densityNoise --pressureNoise --densityNoiseSeed 895268039 --pressureNoiseSeed 2410966965 --caseName densityPressureNoise --nx 32 --dt 0.005
# python regionalShocks.py --regions 1 --timeLimit 4.096 --sdf circle --caseName circleCase --seed 123625573 --nx 64 --dt 0.0025
# python regionalShocks.py --regions 2 --timeLimit 4.096 --caseName dualRegions --seed 123625573 --nx 64 --dt 0.0025
# python regionalShocks.py --regions 4 --timeLimit 4.096 --caseName quadRegions --splitLineX -0.164 --splitLineY -0.321 --seed 123625573 --nx 64 --dt 0.0025
# python regionalShocks.py --regions 1 --timeLimit 4.096 --velocityNoise --seed 123625573 --caseName velocityNoise --nx 64 --dt 0.0025
# python regionalShocks.py --regions 1 --timeLimit 4.096 --densityNoise --pressureNoise --densityNoiseSeed 2792666959 --pressureNoiseSeed 650799304 --caseName densityPressureNoise --nx 64 --dt 0.0025
# python regionalShocks.py --regions 1 --timeLimit 4.096 --sdf circle --caseName circleCase --seed 3375572104 --nx 64 --dt 0.0025
# python regionalShocks.py --regions 2 --timeLimit 4.096 --caseName dualRegions --seed 3375572104 --nx 64 --dt 0.0025
# python regionalShocks.py --regions 4 --timeLimit 4.096 --caseName quadRegions --splitLineX -0.103 --splitLineY -0.149 --seed 3375572104 --nx 64 --dt 0.0025
# python regionalShocks.py --regions 1 --timeLimit 4.096 --velocityNoise --seed 3375572104 --caseName velocityNoise --nx 64 --dt 0.0025
# python regionalShocks.py --regions 1 --timeLimit 4.096 --densityNoise --pressureNoise --densityNoiseSeed 895268039 --pressureNoiseSeed 2410966965 --caseName densityPressureNoise --nx 64 --dt 0.0025
# python regionalShocks.py --regions 1 --timeLimit 4.096 --sdf circle --caseName circleCase --seed 123625573 --nx 128 --dt 0.001
# python regionalShocks.py --regions 2 --timeLimit 4.096 --caseName dualRegions --seed 123625573 --nx 128 --dt 0.001
# python regionalShocks.py --regions 4 --timeLimit 4.096 --caseName quadRegions --splitLineX -0.164 --splitLineY -0.321 --seed 123625573 --nx 128 --dt 0.001
# python regionalShocks.py --regions 1 --timeLimit 4.096 --velocityNoise --seed 123625573 --caseName velocityNoise --nx 128 --dt 0.001
# python regionalShocks.py --regions 1 --timeLimit 4.096 --densityNoise --pressureNoise --densityNoiseSeed 2792666959 --pressureNoiseSeed 650799304 --caseName densityPressureNoise --nx 128 --dt 0.001
# python regionalShocks.py --regions 1 --timeLimit 4.096 --sdf circle --caseName circleCase --seed 3375572104 --nx 128 --dt 0.001
# python regionalShocks.py --regions 2 --timeLimit 4.096 --caseName dualRegions --seed 3375572104 --nx 128 --dt 0.001
# python regionalShocks.py --regions 4 --timeLimit 4.096 --caseName quadRegions --splitLineX -0.103 --splitLineY -0.149 --seed 3375572104 --nx 128 --dt 0.001
# python regionalShocks.py --regions 1 --timeLimit 4.096 --velocityNoise --seed 3375572104 --caseName velocityNoise --nx 128 --dt 0.001
# python regionalShocks.py --regions 1 --timeLimit 4.096 --densityNoise --pressureNoise --densityNoiseSeed 895268039 --pressureNoiseSeed 2410966965 --caseName densityPressureNoise --nx 128 --dt 0.001
# python regionalShocks.py --regions 1 --timeLimit 4.096 --sdf circle --caseName circleCase --seed 123625573 --nx 256 --dt 0.0005
# python regionalShocks.py --regions 2 --timeLimit 4.096 --caseName dualRegions --seed 123625573 --nx 256 --dt 0.0005
# python regionalShocks.py --regions 4 --timeLimit 4.096 --caseName quadRegions --splitLineX -0.164 --splitLineY -0.321 --seed 123625573 --nx 256 --dt 0.0005
# python regionalShocks.py --regions 1 --timeLimit 4.096 --velocityNoise --seed 123625573 --caseName velocityNoise --nx 256 --dt 0.0005
# python regionalShocks.py --regions 1 --timeLimit 4.096 --densityNoise --pressureNoise --densityNoiseSeed 2792666959 --pressureNoiseSeed 650799304 --caseName densityPressureNoise --nx 256 --dt 0.0005
# python regionalShocks.py --regions 1 --timeLimit 4.096 --sdf circle --caseName circleCase --seed 3375572104 --nx 256 --dt 0.0005
# python regionalShocks.py --regions 2 --timeLimit 4.096 --caseName dualRegions --seed 3375572104 --nx 256 --dt 0.0005
# python regionalShocks.py --regions 4 --timeLimit 4.096 --caseName quadRegions --splitLineX -0.103 --splitLineY -0.149 --seed 3375572104 --nx 256 --dt 0.0005
# python regionalShocks.py --regions 1 --timeLimit 4.096 --velocityNoise --seed 3375572104 --caseName velocityNoise --nx 256 --dt 0.0005
# python regionalShocks.py --regions 1 --timeLimit 4.096 --densityNoise --pressureNoise --densityNoiseSeed 895268039 --pressureNoiseSeed 2410966965 --caseName densityPressureNoise --nx 256 --dt 0.0005
# python regionalShocks.py --regions 1 --timeLimit 4.096 --sdf circle --caseName circleCase --seed 123625573 --nx 512 --dt 0.0001
# python regionalShocks.py --regions 2 --timeLimit 4.096 --caseName dualRegions --seed 123625573 --nx 512 --dt 0.0001
# python regionalShocks.py --regions 4 --timeLimit 4.096 --caseName quadRegions --splitLineX -0.164 --splitLineY -0.321 --seed 123625573 --nx 512 --dt 0.0001
# python regionalShocks.py --regions 1 --timeLimit 4.096 --velocityNoise --seed 123625573 --caseName velocityNoise --nx 512 --dt 0.0001
# python regionalShocks.py --regions 1 --timeLimit 4.096 --densityNoise --pressureNoise --densityNoiseSeed 2792666959 --pressureNoiseSeed 650799304 --caseName densityPressureNoise --nx 512 --dt 0.0001
# python regionalShocks.py --regions 1 --timeLimit 4.096 --sdf circle --caseName circleCase --seed 3375572104 --nx 512 --dt 0.0001
# python regionalShocks.py --regions 2 --timeLimit 4.096 --caseName dualRegions --seed 3375572104 --nx 512 --dt 0.0001
# python regionalShocks.py --regions 4 --timeLimit 4.096 --caseName quadRegions --splitLineX -0.103 --splitLineY -0.149 --seed 3375572104 --nx 512 --dt 0.0001
# python regionalShocks.py --regions 1 --timeLimit 4.096 --velocityNoise --seed 3375572104 --caseName velocityNoise --nx 512 --dt 0.0001
# python regionalShocks.py --regions 1 --timeLimit 4.096 --densityNoise --pressureNoise --densityNoiseSeed 895268039 --pressureNoiseSeed 2410966965 --caseName densityPressureNoise --nx 512 --dt 0.0001

# %%
densities
# Out:
# tensor([1.0000, 1.0000, 1.0000,  ..., 2.0000, 2.0000, 2.0000], device='cuda:0')

# %%
import subprocess
import shlex
import imageio.v2 as imageio
from skimage.transform import resize, rescale
from skimage.io import imread

def postProcess(imagePrefix, fps, timesteps, exportName):
    fileList = os.listdir(imagePrefix)
    fileList = [f for f in fileList if f.endswith('.png') and f.startswith('frame_')]
    fileList = sorted(fileList)

    writer = imageio.get_writer(f'{imagePrefix}/output.mp4', fps=50, bitrate='10M')
    for image in fileList:
        writer.append_data(imageio.imread(imagePrefix + image))
    writer.close()

    images = []
    for image in fileList:
        images.append(imread(imagePrefix + image))

    currentImageSize = images[0].shape
    currentLongEdge = max(images[0].shape[0], images[0].shape[1])
    targetLongEdge = 800
    ratio = targetLongEdge / currentLongEdge

    images = [(rescale(image, ratio, anti_aliasing=True, channel_axis=-1)*255).astype('uint8') for image in images]

    # for image in images:
        # print(image.shape)
        # break

    # images = [resizeImageLongEdge(i, 600) for i in images]

    imageio.mimsave(f'{imagePrefix}/output.gif', images, fps=50, loop=0)
    
    print('Copying video to videos folder')
    os.makedirs(f'./videos/', exist_ok= True)
    # subprocess.run(shlex.split(f'cp {imagePrefix}/output.mp4 ./videos/{exportName}.mp4'))
    subprocess.run(shlex.split(f'cp {imagePrefix}/output.gif ./videos/{exportName}.gif'))
    # lastFrameFile = f'{imagePrefix}/frame_{timesteps - 1:05d}.png'
    # subprocess.run(shlex.split(f'cp {lastFrameFile} ./videos/{exportName}.png'))
    # print('Done!')
