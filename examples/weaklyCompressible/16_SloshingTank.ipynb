# %%
# %matplotlib widget
import torch
import warnings
import os
import copy
import subprocess
import shlex
import matplotlib.pyplot as plt
from tqdm import TqdmExperimentalWarning
warnings.filterwarnings("ignore", category=TqdmExperimentalWarning)
from tqdm.autonotebook import tqdm
from torch.profiler import profile,  ProfilerActivity

os.environ['TORCH_CUDA_ARCH_LIST'] = f'{torch.cuda.get_device_properties(0).major}.{torch.cuda.get_device_properties(0).minor}'

from diffSPH.sampling import buildDomainDescription
from diffSPH.modules.adaptiveSmoothingASPH import n_h_to_nH
from diffSPH.plotting import visualizeParticles, updatePlot
from diffSPH.integration import getIntegrator
from diffSPH.util import volumeToSupport
from diffSPH.boundary import sampleDomainSDF
from diffSPH.kernels import Kernel_Scale
from diffSPH.sdf import getSDF, sdfFunctions, operatorDict, sampleSDF
from diffSPH.regions import buildRegion, filterRegion, plotRegions
from diffSPH.modules.timestep import computeTimestep
from diffSPH.schemes.initializers import initializeSimulation, updateBodyParticles
from diffSPH.schemes.deltaSPH import deltaPlusSPHScheme, DeltaPlusSPHSystem
from diffSPH.schema import getSimulationScheme
from diffSPH.enums import *
from exampleUtil import setupExampleSimulation, runSimulation, postProcess
from diffSPH.sampling import sampleDivergenceFreeNoise
import math
from diffSPH.sampling import sampleDivergenceFreeNoise
from diffSPH.modules.particleShifting import solveShifting, shuffleParticles
import numpy as np
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 6439

# %%
simulationName = 'Sloshing Tank'
exportName = f'12_sloshingTank_actual'

L = 1
nx = 128
dx = L / nx
targetDt = 0.0001
rho0 = 1000
freeSurface = True
band = 0
fps = 50
timeLimit = 10

dim = 2
band = 5
aspect = 1/2
CFL = 0.3

W = 0.9/2
H = 0.508/2
F = 0.093

L = W * 2
dx = L/nx
dmin = [-W - dx * band, - dx * band]
dmax = [W + dx * band, 2 * H + dx * band]

kernel = KernelType.Wendland4
scheme = SimulationScheme.DeltaSPH
integrationScheme = IntegrationSchemeType.symplecticEuler

device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')
dtype = torch.float32
targetNeighbors = n_h_to_nH(4, 2)
c_s = 0.3 * volumeToSupport(dx**2, targetNeighbors, 2) / Kernel_Scale(kernel, 2) / targetDt
# c_s = 10
print(f'Computed c_s: {c_s:.2f}')
c_s = 10
exportInterval = 1 / fps
plotInterval = int(math.ceil(exportInterval / targetDt))
timesteps = int(timeLimit / targetDt)

print(f'Using device: {device}')
print(f'Using kernel: {kernel.name}, target neighbors: {targetNeighbors}, c_s: {c_s:.2f}')
# Out:
# Computed c_s: 38.86
# Using device: cuda:0
# Using kernel: Wendland4, target neighbors: 50.26548245743669, c_s: 10.00

# %%
dx
# Out:
# 0.00703125

# %%
# dmin = [-0.7, -0.2]
# dmax = [0.7, 0.8]
domain = buildDomainDescription(l = L + dx * (band) * 2, dim = dim, periodic = True, device = device, dtype = dtype)
domain.min = torch.tensor([dmin[0] - dx*band, dmin[1] - dx*band], device = device, dtype = dtype)
domain.max = torch.tensor([dmax[0] + dx*band, dmax[1] + dx*band], device = device, dtype = dtype)


domain = buildDomainDescription(l = L + dx * (band) * 2, dim = dim, periodic = True, device = device, dtype = dtype)
domain.min = torch.tensor([-L/2/ aspect - dx*band, -L/2 - dx * band], device = device, dtype = dtype)
domain.max = torch.tensor([L/2/ aspect + dx*band, L/2 + dx * band], device = device, dtype = dtype)

domain.min = torch.tensor([dmin[0] - dx*band, dmin[1] - dx*band], device = device, dtype = dtype)
domain.max = torch.tensor([dmax[0] + dx*band, dmax[1] + dx*band], device = device, dtype = dtype)

interiorDomain = buildDomainDescription(l = L, dim = dim, periodic = True, device = device, dtype = dtype)
interiorDomain.min = torch.tensor([-L/2 / aspect, -L/2], device = device, dtype = dtype)
interiorDomain.max = torch.tensor([L/2/ aspect, L/2], device = device, dtype = dtype)
interiorDomain.min = torch.tensor([dmin[0], dmin[1]], device = device, dtype = dtype)
interiorDomain.max = torch.tensor([dmax[0], dmax[1]], device = device, dtype = dtype)

wrappedKernel = kernel

simulator, SimulationSystem, config, integrator = getSimulationScheme(
     scheme, kernel, integrationScheme, 
     1.0, targetNeighbors, domain)
integrationScheme = getIntegrator(integrationScheme)


config['domain'] = domain

config['particle'] = {
    'nx': nx + 2 * band,
    'dx': L/nx,
    'targetNeighbors': targetNeighbors,
    'band': band
}
config['fluid'] = {
    'rho0': rho0,
    'c_s': c_s
}
config['surfaceDetection']['active'] = freeSurface
config['shifting']['freeSurface'] = freeSurface
config['pressure']['term'] = 'nonConservative'
# config['shifting']['active'] = False

config['gravity'] = {
    'active': True,
    'magnitude': 9.8,
    'mode': 'directional',
    'direction': torch.tensor([0, -1], device = device, dtype = dtype)
}
config['shifting']['projectionScheme'] = 'derp'
config['shifting']['active'] = True

# %%
dx
# Out:
# 0.00703125

# %%
fluid_sdf = lambda x: sampleDomainSDF(x, domain, invert = True)
domain_sdf = lambda x: sampleDomainSDF(x, interiorDomain, invert = False)
obstacle_sdf = lambda points: sampleSDF(points, lambda x: getSDF('circle')['function'](x, torch.tensor(1/4).to(points.device)), invert = False)


fluid = lambda points: sampleSDF(points, operatorDict['translate'](lambda x: getSDF('box')['function'](x, torch.tensor([W,F]).to(points.device)), torch.tensor([0,0]).to(points.device)), invert = False)

# fluid = lambda points: sampleSDF(points, operatorDict['translate'](lambda x: getSDF('box')['function'](x, torch.tensor([dx * 17,F]).to(points.device)), torch.tensor([0,dx * 15]).to(points.device)), invert = False)

box_offset = 0

box_outer = operatorDict['translate'](lambda x: getSDF('box')['function'](x, torch.tensor([W + dx * band,H + dx * band + box_offset * dx]).to(device)), torch.tensor([0, H - box_offset * dx]).to(device))
box_inner = operatorDict['translate'](lambda x: getSDF('box')['function'](x, torch.tensor([W,H]).to(device)), torch.tensor([0, H]).to(device))

box_inner_ = operatorDict['invert'](box_inner)
box_outer_ = operatorDict['invert'](box_outer)

combined_sdf = lambda points: sampleSDF(points, operatorDict['union'](box_outer_, box_inner), invert = True)
# combined_sdf = lambda points: sampleSDF(points, box_inner_, False)

regions = []

regions.append(buildRegion(sdf = fluid, config = config, type = 'fluid'))
regions.append(buildRegion(sdf = combined_sdf, config = config, type = 'boundary', kind = 'driven'))
regions[-1]['sdf'] = lambda points: sampleSDF(points, box_inner, invert = True)
# regions.append(buildRegion(sdf = inlet_sdf, config = config, type = 'inlet', dirichletValues={'densities': config['fluid']['rho0'], 'velocities': torch.tensor([1,0], device = device, dtype = dtype)}, updateValues = {'densities': 0, 'velocities': torch.tensor([0,0], device = device, dtype = dtype)}))

# regions.append(buildRegion(sdf = outlet_sdf, config = config, type = 'outlet'))
# regions.append(buildRegion(sdf = outletBuffer_sdf, config = config, type = 'buffer', bufferValues = ['densities', 'velocities', 'pressures']))

# regions.append(buildRegion(sdf = box_sdf, config = config, type = 'dirichlet', dirichletValues={'densities': 2.0, 'velocities': torch.tensor([1,2], device = device, dtype = dtype), 'pressures': lambda x: torch.where(x[:,0] > 0, 0.0, 1.0)}, updateValues = {'densities': 2.0}))


for region in regions:
    region = filterRegion(region, regions)


fig, axis = plt.subplots(1, 1, figsize=(10, 5), squeeze=False)
    
# plotRegions(regions, axis[0,0], plotFluid = True, plotParticles = True)

# for region in regions:
#     axis[0,0].scatter(region['particles'].positions[:,0].cpu().numpy(), region['particles'].positions[:,1].cpu().numpy(), s=1, c = 'blue' if region['type'] == 'fluid' else 'orange')

axis[0,0].set_aspect('equal', adjustable='box')

rectangle = plt.Rectangle((domain.min[0].cpu().numpy(), domain.min[1].cpu().numpy()), domain.max[0].cpu().numpy() - domain.min[0].cpu().numpy(), domain.max[1].cpu().numpy() - domain.min[1].cpu().numpy(), fill=False, color='black', lw=2)
axis[0,0].add_patch(rectangle)

rectangleInterior = plt.Rectangle((interiorDomain.min[0].cpu().numpy(), interiorDomain.min[1].cpu().numpy()), interiorDomain.max[0].cpu().numpy() - interiorDomain.min[0].cpu().numpy(), interiorDomain.max[1].cpu().numpy() - interiorDomain.min[1].cpu().numpy(), fill=False, color='red', lw=2)
axis[0,0].add_patch(rectangleInterior)

from matplotlib.patches import Rectangle

rect = Rectangle(
    xy = [-0.45, 0],
    width = 0.9,
    height = 0.508,
    edgecolor = 'green',
    fill = False
)
axis[0,0].add_patch(rect)

rect = Rectangle(
    xy = [-0.45, 0],
    width = 0.9,
    height = 0.093,
    edgecolor = 'purple',
    fill = False
)
axis[0,0].add_patch(rect)

fig.tight_layout()

from diffSPH.schemes.initializers import *

config['regions'] = regions
particleState_ = initializeWeaklyCompressibleState(regions, config)[0]

particleState_.positions[particleState_.kinds == 1] += torch.randn_like(particleState_.positions[particleState_.kinds == 1]) * dx * 0.0125
# particleState_.positions[particleState_.kinds == 0] += torch.randn_like(particleState_.positions[particleState_.kinds == 0]) * dx * 0.025

particleState = addBoundaryGhostParticles(regions, particleState_)
particleState, emitted = processInlets(particleState, config, config['domain'])
# particleState.densities[:] = config['fluid']['rho0']
# particleState.velocities = forcing(particleState.positions)

# neighborhood, sparseNeighborhood_ = buildNeighborhood(particleState, particleState, config['domain'], verletScale = config['neighborhood']['verletScale'], mode = 'superSymmetric', priorNeighborhood=None)         
# ghostNeighbors = filterNeighborhoodByKind(particleState, sparseNeighborhood_, which = 'fluidToGhost')


minPos = particleState.positions.min(dim=0).values
print('Min Position:', minPos)
mask = torch.logical_and(particleState.positions[:,1] < minPos[1] + dx * 0.75, particleState.kinds == 1)
particleState.masses[mask] *= 0.0

print(f'Minimum Mass: {particleState.masses.min().cpu().numpy()}, Maximum Mass: {particleState.masses.max().cpu().numpy()}')

    # mass = torch.sum(masses)
    # centerOfMass = torch.sum(masses.view(-1,1) * positions, dim = 0) / mass

boundaryparticles = particleState.kinds == 1


unadjustedCenterOfMass = (particleState.positions[boundaryparticles] * particleState.masses[boundaryparticles].unsqueeze(-1)).sum(dim=0) / particleState.masses[boundaryparticles].sum()
maskParticles = torch.sum(mask)

print('Unadjusted Center of Mass:', unadjustedCenterOfMass.cpu().numpy())
print('Number of Masked Particles:', maskParticles.cpu().numpy())

targetCenterOfMass = torch.tensor([0.0, 0.0], device = device, dtype = dtype)
adjustment = targetCenterOfMass - unadjustedCenterOfMass
print('Adjustment:', adjustment.cpu().numpy())

# At this  point we have a single row of maskParticles at the bottom of the box
# We now adjust the _mass_ of these particles to shift the center of mass to the target location
# Solve for new mass value m such that

originalMass = particleState.masses[particleState.kinds == 1].sum()
originalCoM = unadjustedCenterOfMass

m = particleState.masses[particleState.kinds==1].max()
particleState.masses[mask] = m

additionalMass = m * maskParticles
additionalCoM = particleState.positions[mask].mean(dim=0)

print('Original Mass:', originalMass.cpu().numpy())
print('Additional Mass:', additionalMass.cpu().numpy())
print('Original CoM:', originalCoM.cpu().numpy())
print('Additional CoM:', additionalCoM.cpu().numpy())

combinedMass = originalMass + additionalMass
combinedCoM = (originalMass * originalCoM + additionalMass * additionalCoM) / combinedMass
print('Combined Mass:', combinedMass.cpu().numpy())
print('Combined CoM:', combinedCoM.cpu().numpy())

# Now we want to solve for m such that the combined center of mass is at the target location
# targetCenterOfMass = (originalMass * originalCoM + m * additionalCoM) / (originalMass + m)
# Solve for m:
# targetCoM * (originalMass + m) = originalMass * originalCoM + m * additionalCoM
# targetCoM * originalMass + targetCoM * m = originalMass * originalCoM + m * additionalCoM
# targetCoM * m - m * additionalCoM = originalMass * originalCoM - targetCoM * originalMass
# m * (targetCoM - additionalCoM) = originalMass * (originalCoM - targetCoM)
# m = originalMass * (originalCoM - targetCoM) / (targetCoM - additionalCoM)

m = originalMass * (originalCoM - targetCenterOfMass) / (targetCenterOfMass - additionalCoM)
m = m / maskParticles
print('New Mass per Masked Particle:', m.cpu().numpy())
particleState.masses[mask] = m[1]




rigidBodyIDs = torch.unique(particleState.materials[particleState.kinds == 1]).cpu().numpy()
# print(rigidBodyIDs)
rigidBodies = []
for id in rigidBodyIDs:
    # print('Processing rigid body', id)
    rigidBody = buildRigidBody(particleState, config, id)
    if(rigidBody is not None):
        rigidBodies.append(rigidBody)

rigidBodies[-1].angularVelocity = np.pi/2

# rigidBodies[0].angularVelocity = np.pi / 2
for rigidBody in rigidBodies:
    particleState = updateBodyParticlesWCSPH(particleState, rigidBody)
config['rigidBodies'] = rigidBodies
# return particleState, config, rigidBodies

axis[0,0].scatter(rigidBodies[-1].centerOfMass[0].cpu().numpy(), rigidBodies[-1].centerOfMass[1].cpu().numpy(), s=50, c='red', marker='x')

print(f'Rigid Body Center of Mass: {rigidBodies[-1].centerOfMass.cpu().numpy()}')

sc = axis[0,0].scatter(particleState.positions[boundaryparticles,0].cpu().numpy(), particleState.positions[boundaryparticles,1].cpu().numpy(), s=1, c = particleState.masses[boundaryparticles].cpu().numpy())
# sc = axis[0,0].scatter(particleState.positions[boundaryparticles,0].cpu().numpy(), particleState.positions[boundaryparticles,1].cpu().numpy(), s=1, c = particleState.velocities[boundaryparticles][:,1].cpu().numpy())


fig.colorbar(sc, ax=axis[0,0], label='Mass of Boundary Particles')
axis[0,0].scatter(particleState.positions[particleState.kinds==0,0].cpu().numpy(), particleState.positions[particleState.kinds==0,1].cpu().numpy(), s=1, c = 'blue')


print(sum([region['particles'].positions.shape[0] for region in regions]))
# Out:
# Min Position: tensor([-0.4854, -0.0353], device='cuda:0')
# Minimum Mass: 0.0, Maximum Mass: 0.022091707214713097
# Unadjusted Center of Mass: [7.786936e-07 2.797045e-01]
# Number of Masked Particles: 416
# Adjustment: [-7.786936e-07 -2.797045e-01]
# Original Mass: 102.50552
# Additional Mass: 9.19015
# Original CoM: [7.786936e-07 2.797045e-01]
# Additional CoM: [ 8.6998070e-06 -3.2715805e-02]
# Combined Mass: 111.69567
# Combined CoM: [1.4304308e-06 2.5399905e-01]
# New Mass per Masked Particle: [-0.0220552  2.1066666]
# Rigid Body Center of Mass: [7.8691073e-06 2.4356293e-09]
# 8896
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
particleState.masses.max()
# Out:
# tensor(2.1067, device='cuda:0')

# %%
# config['EOS']['type'] = 'stiffTait'

# %%
import pandas as pd
rollHistory = pd.read_csv('roof_water_1x.txt', sep='\t')

display(rollHistory)

fig, axis = plt.subplots(3, 1, figsize=(8, 6), squeeze=False)

dt = rollHistory['Time[s]'][1] - rollHistory['Time[s]'][0]

rollTimes = rollHistory['Time[s]'].to_numpy()
pressure = rollHistory['Pressure[mbar]'].to_numpy()
positionOriginal = rollHistory['Position_original [deg]'].to_numpy()
positionSmooth = rollHistory['Position_smooth_splines [deg]'].to_numpy()

velocity = rollHistory['Velocity[deg\\s]'].to_numpy()
acceleration = rollHistory['Aceleration[deg\\s2]'].to_numpy()

axis[0,0].plot(rollTimes, pressure)
axis[0,0].set_ylabel('Pressure [mbar]')
axis[0,0].set_title('Pressure Reading')

axis[1,0].plot(rollTimes, positionOriginal)
axis[1,0].plot(rollTimes, positionSmooth)
axis[1,0].set_ylabel('Roll Angle [deg]')
axis[1,0].set_title('Roll Angle')

axis[2,0].plot(rollTimes, velocity, label='Velocity[deg/s]')
axis[2,0].plot(rollTimes, acceleration, label='Acceleration[deg/s2]')
axis[2,0].set_ylabel('Velocity / Acceleration')
axis[2,0].set_title('Velocity and Acceleration')
axis[2,0].legend()  
fig.tight_layout()
# Out:
#         Time[s]  Pressure[mbar]  Position_smooth_splines [deg]  \
# 0       0.00000        0.119914                   1.387779e-17
# 1       0.00005        0.213180                   1.929147e-08
# 2       0.00010        0.133238                   7.719154e-08
# 3       0.00015       -0.053295                   1.737387e-07
# 4       0.00020        0.159885                   3.089715e-07
# ...         ...             ...                            ...
# 121596  6.07980       -0.626217                  -5.980536e-02
# 121597  6.07985       -0.932664                  -5.873440e-02
# 121598  6.07990       -0.692836                  -5.766343e-02
# 121599  6.07995       -0.652865                  -5.659247e-02
# 121600  6.08000       -0.706160                  -5.552151e-02
#
#         Velocity[deg\s]  Aceleration[deg\s2]  Position_original [deg]
# 0          2.775558e-16            15.428041             1.143341e-09
# ...

# %%
dmin = [-W - dx * band, - dx * band]
dmax = [W + dx * band, 2 * H + dx * band]

dmin = [-0.7, -0.6]
dmax = [0.7, 0.8]
domain = buildDomainDescription(l = L + dx * (band) * 2, dim = dim, periodic = True, device = device, dtype = dtype)
domain.min = torch.tensor([dmin[0] - dx*band, dmin[1] - dx*band], device = device, dtype = dtype)
domain.max = torch.tensor([dmax[0] + dx*band, dmax[1] + dx*band], device = device, dtype = dtype)

config['domain'] = domain
from diffSPH.sampling import sampleDivergenceFreeNoise

# particleState, config, rigidBodies = initializeSimulation(scheme, config, regions)

# velocities = sampleDivergenceFreeNoise(particleState, domain, config, nx * 2, octaves = 3, lacunarity = 2, persistence = 0.5, baseFrequency = 1, tileable = True, kind = 'perlin', seed = 45906734)
# particleState.velocities[:] = velocities
import numpy as np
t = torch.tensor(0, device = device, dtype = dtype)
rigidBodies[-1].angularVelocity = np.pi/16 * torch.cos(t * np.pi)
# rigidBodies[-1].centerOfMass = torch.tensor([0.0, 0.0], device = device, dtype = dtype)

# %%
config['EOS'] = {'type': 'stiffTait'}

# %%
figsize = (11,10)
markerSize = 2

dt = computeTimestep(scheme, 1e-2, particleState, config, None)
particles = copy.deepcopy(particleState)
particleSystem = DeltaPlusSPHSystem(config['domain'], None, 0., copy.deepcopy(particleState), 'momentum', None, rigidBodies = config['rigidBodies'], regions = config['regions'], config = config)

for rigidBody in config['rigidBodies']:
    particleState = updateBodyParticles(scheme, particleState, rigidBody)

print(dt)
# Out:
# tensor(0.0003, device='cuda:0')

# %%
config['neighborhood']['verletScale'] = 1

# %%
## Setup values for plotting 

kineticEnergy = 0.5 * particleState.densities * (particleState.velocities ** 2).sum(1)

t = 0
E_k0 = 0.5 * particleState.masses * torch.linalg.norm(particleState.velocities, dim = -1)**2
E_k = 0.5 * particleState.masses * torch.linalg.norm(particleState.velocities, dim = -1)**2

rhoMin = particleState.densities.min().detach().cpu().item() / config['fluid']['rho0']
rhoMean = particleState.densities.mean().detach().cpu().item() / config['fluid']['rho0']
rhoMax = particleState.densities.max().detach().cpu().item() / config['fluid']['rho0']

initialVelocity = particleState.velocities.clone()
initialDensities = particleState.densities.clone()
initialPotentialEnergy = None

if config['gravity']['active']:
    if 'mode' in config['gravity'] and config['gravity']['mode'] == 'potential':
        B = config['gravity']['magnitude']
        initialPotentialEnergy = 0.5 * B**2 * particleState.masses / config['fluid']['rho0'] * particleState.densities * torch.linalg.norm(particleState.positions, dim = -1)**2

initialKineticEnergy = 0.5 * particleState.masses / config['fluid']['rho0'] * particleState.densities * torch.linalg.norm(initialVelocity, dim = -1)**2
initialEnergy = initialKineticEnergy + initialPotentialEnergy if initialPotentialEnergy is not None else initialKineticEnergy

fig, axis = plt.subplots(1, 1, figsize = figsize, squeeze=False)

axes = axis.flatten()

markerSize = 0.5
velocityPlot = visualizeParticles(fig, axes[0], 
            particles = particleSystem.systemState, 
            domain = config['domain'], 
            quantity = particleSystem.systemState.velocities, 
            which = 'both',
            mapping = 'L2',
            cmap = 'viridis',
            visualizeBoth=True,
            kernel = config['kernel'],
            plotDomain = False,
            gridVisualization=False, markerSize=markerSize, streamLines=False)

# axis[0,0].scatter(particleSystem.systemState.positions[particleSystem.systemState.kinds==2,0].cpu().numpy(), particleSystem.systemState.positions[particleSystem.systemState.kinds==2,1].cpu().numpy(), s=1, c = 'orange')

axis[0,0].set_title(r'$\rho$')

totalInitialEnergy = (initialEnergy).sum().detach().cpu().item()
totalEnergy = (initialEnergy).sum().detach().cpu().item()

fig.suptitle(f'{simulationName}, ptcls = {particleState.positions.shape[0]}, kernel = {config["kernel"].name}, neighbors = {config["targetNeighbors"]:.2g}, $c_s$ = {config["fluid"]["c_s"]:.1f}\n$\\rho$ = [{rhoMin:.4g} | {rhoMean:.4g} | {rhoMax:.4g}], $E_0$ = {totalInitialEnergy:.4g}, $E$ = {totalEnergy:.4g}, $\\Delta E$ = {totalEnergy - totalInitialEnergy:.4g}, $t$ = {particleSystem.t:.4g}, $\Delta t$ = {dt:.2e}')

for ax in axis.flatten():
        ax.set_xlim(dmin[0], dmax[0])
        ax.set_ylim(dmin[1], dmax[1])

fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
t = torch.tensor(0.0, device = device, dtype = dtype)
dt = 0.0001
data_dt = rollTimes[1] - rollTimes[0]
numSteps = rollTimes[-1] / data_dt
currentStep = int(t.cpu().item() // dt)
currentAngle = positionSmooth[currentStep] * np.pi / 180
angularVelocity = velocity[currentStep] * np.pi / 180

# particleSystem.rigidBodies[-1].angle = currentAngle
rigidBodies[-1].angularVelocity = angularVelocity
particleSystem.rigidBodies[-1].angularVelocity = angularVelocity

print(f'Starting simulation for {numSteps} steps with dt = {dt:.5f}')
print(f'Current Step: {currentStep:.2f}')
print(f'Current Angle: {currentAngle:.5f} rad, Current Angular Velocity: {angularVelocity:.5f} rad/s')

timesteps = rollTimes[-1] // dt + 1
timesteps = int(timesteps)

plotInterval = 40
# Out:
# Starting simulation for 121600.0 steps with dt = 0.00010
# Current Step: 0.00
# Current Angle: 0.00000 rad, Current Angular Velocity: 0.00000 rad/s

# %%
plotInterval
# Out:
# 40

# %%
os.makedirs(f'output/{exportName}', exist_ok=True)

# %%
for i in (tq:=tqdm(range(timesteps))):
    data_dt = rollTimes[1] - rollTimes[0]
    numSteps = rollTimes[-1] / data_dt
    currentStep = int(t.cpu().item() // data_dt)
    currentAngle = positionSmooth[currentStep] * np.pi / 180
    angularVelocity = velocity[currentStep] * np.pi / 180

    angularVelocity = angularVelocity * 0

    # particleSystem.rigidBodies[-1].angle = currentAngle
    # rigidBodies[-1].angularVelocity = angularVelocity / 5
    particleSystem.rigidBodies[-1].angularVelocity = angularVelocity# / 5
    particleSystem.rigidBodies[-1].angularVelocity = np.pi/4
    particleSystem.priorStep = None

    particleSystem, currentState, updates = integrationScheme.function(particleSystem, dt, simulator, config, priorStep = particleSystem.priorStep, verbose = False)
    t += dt
    
    # break
    if i % plotInterval == plotInterval - 1 or i == timesteps - 1:

        rhoMin = particleSystem.systemState.densities.min().detach().cpu().item() / config['fluid']['rho0']
        rhoMean = particleSystem.systemState.densities.mean().detach().cpu().item() / config['fluid']['rho0']
        rhoMax = particleSystem.systemState.densities.max().detach().cpu().item() / config['fluid']['rho0']

        kineticEnergy = 0.5 * particleSystem.systemState.masses / config['fluid']['rho0'] * particleSystem.systemState.densities * torch.linalg.norm(particleSystem.systemState.velocities, dim = -1)**2
        potentialEnergy = None
        if config['gravity']['active']:
            if 'mode' in config['gravity'] and config['gravity']['mode'] == 'potential':
                B = config['gravity']['magnitude']
                potentialEnergy = 0.5 * B**2 * particleSystem.systemState.masses / config['fluid']['rho0'] * particleSystem.systemState.densities * torch.linalg.norm(particleSystem.systemState.positions, dim = -1)**2
                
        combinedEnergy = kineticEnergy + potentialEnergy if potentialEnergy is not None else kineticEnergy
        totalInitialEnergy = (initialEnergy).sum().detach().cpu().item()
        totalEnergy = (combinedEnergy).sum().detach().cpu().item()

        fig.suptitle(f'{simulationName}, ptcls = {particleSystem.systemState.positions.shape[0]}, kernel = {config["kernel"].name}, neighbors = {config["targetNeighbors"]:.2g}, $c_s$ = {config["fluid"]["c_s"]:.1f}\n$\\rho$ = [{rhoMin:.4g} | {rhoMean:.4g} | {rhoMax:.4g}], $E_0$ = {totalInitialEnergy:.4g}, $E$ = {totalEnergy:.4g}, $\\Delta E$ = {totalEnergy - totalInitialEnergy:.4g}, $t$ = {particleSystem.t:.4g}, $\Delta t$ = {dt:.2e}\nRoll Angle = {currentAngle * 180 / np.pi:.2f} deg, Roll Angular Velocity = {angularVelocity * 180 / np.pi:.2f} deg/s, Actual: {particleSystem.rigidBodies[-1].orientation * 180 / np.pi:.2f} deg')
        updatePlot(velocityPlot, particleSystem.systemState, particleSystem.systemState.velocities)
        # updatePlot(densityPlot, particleSystem.systemState, particleSystem.systemState.densities)
        # updatePlot(uidPlot, particleSystem.systemState, particleSystem.systemState.UIDs)
        fig.canvas.draw()
        fig.canvas.flush_events()

        fig.savefig(f'output/{exportName}/frame_{i:05d}.png', dpi=150)
    # break
# Out:
#   0%|          | 0/60800 [00:00<?, ?it/s]
# [deltaSPH] - [Update] - Boundary viscosity: None
# [mDBC] - Total checks: 8801
# [mDBC] - Check A (r_ib > 1.25 * n_b): 694 [check_a shape: torch.Size([8801])]
# [mDBC] - Check B (dot(x_ib, n_b) > 0.75 * n_b): 0 [check_b shape: torch.Size([8801])]
# [mDBC] - Check AB (A and B): 0
# [mDBC] - Direction 0: No penetration corrections applied.
# [mDBC] - Direction 1: No penetration corrections applied.
# ----------------------------------------
# [mDBC] - Total penetration corrections applied: 0 [827 / 0 / 0] / 13952
# [mDBC] - Average penetration correction magnitude: 0.000000
# [mDBC] - Max penetration correction magnitude: 0.000000
# [deltaSPH] - [Update] - Boundary viscosity: None
# [mDBC] - Total checks: 8801
# [mDBC] - Check A (r_ib > 1.25 * n_b): 694 [check_a shape: torch.Size([8801])]
# [mDBC] - Check B (dot(x_ib, n_b) > 0.75 * n_b): 0 [check_b shape: torch.Size([8801])]
# [mDBC] - Check AB (A and B): 0
# ...

# %%
dt
# Out:
# 0.0005

# %%
fig, axis = plt.subplots(1, 1, figsize = figsize, squeeze=False)

axes = axis.flatten()

# markerSize = 1
velocityPlot = visualizeParticles(fig, axes[0], 
            particles = particleSystem.systemState, 
            domain = config['domain'], 
            quantity = particleSystem.systemState.masses, 
            which = 'both',
            mapping = '.x',
            cmap = 'viridis',
            visualizeBoth=True,
            kernel = config['kernel'],
            plotDomain = False,
            gridVisualization=False, markerSize=markerSize, streamLines=False)

# axis[0,0].scatter(particleSystem.systemState.positions[particleSystem.systemState.kinds==2,0].cpu().numpy(), particleSystem.systemState.positions[particleSystem.systemState.kinds==2,1].cpu().numpy(), s=1, c = 'orange')

axis[0,0].set_title(r'$|\mathbf{u}|$')

totalInitialEnergy = (initialEnergy).sum().detach().cpu().item()
totalEnergy = (initialEnergy).sum().detach().cpu().item()

fig.suptitle(f'{simulationName}, ptcls = {particleState.positions.shape[0]}, kernel = {config["kernel"].name}, neighbors = {config["targetNeighbors"]:.2g}, $c_s$ = {config["fluid"]["c_s"]:.1f}\n$\\rho$ = [{rhoMin:.4g} | {rhoMean:.4g} | {rhoMax:.4g}], $E_0$ = {totalInitialEnergy:.4g}, $E$ = {totalEnergy:.4g}, $\\Delta E$ = {totalEnergy - totalInitialEnergy:.4g}, $t$ = {particleSystem.t:.4g}, $\Delta t$ = {dt:.2e}')

for ax in axis.flatten():
        ax.set_xlim(dmin[0], dmax[0])
        ax.set_ylim(dmin[1], dmax[1])

fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
